# %%
# Making a map using the folium module
import folium
capitals = folium.Map()

# Arbitrary Countries of your choice
countries = [
     {'loc': [-15.794229,-47.882166], 'label': 'Brazil: Brasilia'},
     {'loc': [23.634501, -102.552784], 'label' :'Mexico : Mexico City'},
     {'loc': [38.907192, -77.036871],  'label': 'USA: DC'},
    {'loc': [39.925533, 32.866287],    'label': 'Turkey: Ankara'},
    {'loc': [35.652832, 139.839478],   'label': 'Japan: Tokyo'},
    {'loc': [52.520008, 13.404954],    'label': 'Germany: Berlin'},
    {'loc': [45.421530, -75.697193],   'label': 'Canada : Ottowa'},
    {'loc': [28.613939, 77.209021],    'label': 'India : New Delhi'} ] 

# Adding markers to the map.
for city in countries:
    marker = folium.Marker(location=city['loc'], popup=city['label'])
    marker.add_to(capitals)
#Line adding

''''line_to_new_delhi = folium.PolyLine(
    [[-15.794229,-47.882166],
     [23.634501, -102.552784],
     [38.907192, -77.036871],
     [39.925533, 32.866287],  
     [35.652832, 139.839478], 
     [52.520008, 13.404954],
     [45.421530, -75.697193], 
     [28.613939, 77.209021]] ).add_to(capitals)'''
# The last object in the cell always gets shown in the notebook
capitals
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
